# %%
import streamlit as st
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
dat = pd.read_csv('res.csv')

# %%
fig = sns.relplot(data =dat, x = 'Dpred',y='alphapred')
fig.set(xlim=(0,10))
plt.show()

D = dat['Dpred'].to_numpy()
#D = D[D<10]
#D = D[D>-1]
hist , bins= np .histogram(D,bins=10)

plt.plot(bins[:-1],hist)
plt.show()

# %%
dat = pd.read_csv('/Users/nathanquiblier/Desktop/spt_ct1/data/SPT:MB_ABC4M_format.txt')

# %%
idx = (dat['f']<50)&(dat['traj']<200)&(dat['Dtrue']==10)
dat = dat.loc[idx,:]
dat.to_csv('test_simu.csv')
